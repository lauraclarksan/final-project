# %%
# !pip install pandasql
! pip install sqlalchemy
! pip install PyMySQL
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26772 sha256=032ed52f2c1f03d90ea938277caff47a1f48e47cac250cd520f1b33abfb5c68f
#   Stored in directory: /Users/clark/Library/Caches/pip/wheels/68/5d/a5/edc271b998f909801d7956959f699b976cc9896075dc47c153
# Successfully built pandasql
# ...

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
from pandasql import sqldf
import getpass  
password = getpass.getpass()
# Out:
# ········

# %%
df = pd.read_csv("/Users/clark/Desktop/ironhack/final-project/files/Cleaned dataset.csv", delimiter=",")
df
# Out:
#        Property ID                           Neighborhood  Average Daily Rate  \
# 0         13969432  Sant Pere, Santa Caterina i la Ribera              109.19
# 1         13979120                         la Barceloneta               96.00
# 2         13986464         la Nova Esquerra de l'Eixample              184.95
# 3         13992866                            Sant Antoni               84.05
# 4         14004632                 la Dreta de l'Eixample              320.97
# ...            ...                                    ...                 ...
# 15830      6715955                           el Poble Sec                0.00
# 15831      6724259                     la Sagrada Família                0.00
# 15832      6726949                      la Vila de Gràcia                0.00
# 15833      6776396                 Sant Gervasi - Galvany                0.00
# 15834      6785460                     la Sagrada Família                0.00
#
# ...

# %%
# Define your SQL-like query
query = "SELECT Neighborhood, SUM(`Annual Revenue`) AS `Total Annual Revenue` FROM df GROUP BY Neighborhood ORDER BY `Total Annual Revenue` DESC LIMIT 1"

# %%
# Execute the query
result = sqldf(query)

# Display the result
print(result)
# Out:
#              Neighborhood  Total Annual Revenue
# 0  la Dreta de l'Eixample            93097617.0
