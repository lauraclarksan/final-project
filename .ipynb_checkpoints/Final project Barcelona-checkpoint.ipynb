# %% [markdown]
# # Final Project

# %% [markdown]
# This project focuses on analyzing Airbnb property performance data in the United States over the last 12 months (April 2023 - March 2024).
# The dataset includes key metrics such as Average Daily Rates (ADRs), Revenue, Occupancy rates, and property details including # of bedrooms, # of bathrooms, State and Zipcode. The objective is to provide insights for investors seeking to identify the best places to invest in Airbnb properties based on their preferred metrics. By analyzing factors such as location, property amenities, and guest preferences, investors can optimize their investment strategy to maximize revenue and return on investment.

# %%
# Import necessary libraries

import pandas as pd

# %%
# Load the 1st dataset: annual performances (April 2023 - March 2024)

annual_df = pd.read_csv("/Users/clark/Desktop/ironhack/final-project/files/Spain-barcelona_LTM_Property_Extended_Match_2024-05-04.csv", delimiter = ",")
annual_df
# Out:
# /var/folders/6v/6h31846s6kl6bbfcc310q4gc0000gp/T/ipykernel_44826/772855532.py:3: DtypeWarning: Columns (23,45,51,59,60,62,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   annual_df = pd.read_csv("/Users/clark/Desktop/ironhack/final-project/files/Spain-barcelona_LTM_Property_Extended_Match_2024-05-04.csv", delimiter = ",")
#         Property ID                                      Listing Title  \
# 0       ab-13966456                              Double room in Gracia
# 1       ab-13966494             Room and bright and cosy flat in RAVAL
# 2       ab-13967114                     Habitación compartida en Sants
# 3       ab-13969432          Acogedor apartamento. Luminoso y soleado.
# 4       ab-13972983                                        Double room
# ...             ...                                                ...
# 28667  ha-6715955ha  Tapioles - 2 bed apartment with big balcony in...
# 28668  ha-6724259ha               110m2 apartment to rent in Barcelona
# 28669  ha-6726949ha                     Cozy Gaudí Apartment in Gracia
# 28670  ha-6776396ha  APTO. LOFT 2 - Apartment for 4 people in Barce...
# 28671  ha-6785460ha  Next to the Sagrada Família with terrace and s...
#
#       Property Type     Listing Type Created Date Last Scraped Date Country  \
# 0              Home      Shared room   2016-07-11        2024-04-21   Spain
# 1       Rental unit     Private room   2016-07-11        2024-04-18   Spain
# 2       Rental unit     Private room   2023-05-14        2024-01-22   Spain
# 3       Rental unit  Entire home/apt   2019-07-22        2024-04-29   Spain
# 4       Rental unit     Private room   2016-07-12        2024-04-17   Spain
# ...             ...              ...          ...               ...     ...
# 28667     Apartment  Entire home/apt          NaN        2024-04-30   Spain
# 28668     Apartment  Entire home/apt          NaN        2024-04-29   Spain
# 28669     Apartment  Entire home/apt          NaN        2024-05-01   Spain
# 28670     Apartment  Entire home/apt          NaN        2024-03-20   Spain
# 28671     Apartment  Entire home/apt          NaN        2024-04-30   Spain
#
#            State       City  Zipcode  ... Integrated Property Manager  \
# 0      Barcelona  Barcelona      NaN  ...                         NaN
# 1      Barcelona  Barcelona      NaN  ...                         NaN
# 2      Barcelona  Barcelona      NaN  ...                         NaN
# 3      Barcelona  Barcelona      NaN  ...                         NaN
# 4      Barcelona  Barcelona      NaN  ...                         NaN
# ...          ...        ...      ...  ...                         ...
# 28667  Barcelona  Barcelona      NaN  ...                       False
# 28668  Barcelona  Barcelona      NaN  ...                        True
# 28669  Barcelona  Barcelona      NaN  ...                        True
# 28670  Barcelona  Barcelona      NaN  ...                        True
# 28671  Barcelona  Barcelona      NaN  ...                        True
#
#                                                Amenities  \
# 0      ["elevator", "breakfast", "wireless_internet",...
# 1      ["elevator", "wireless_internet", "kitchen", "...
# 2      ["elevator", "breakfast", "wireless_internet",...
# 3      ["elevator", "wireless_internet", "kitchen", "...
# 4      ["elevator", "wireless_internet", "kitchen", "...
# ...                                                  ...
# 28667  ["Essentials|Linens provided", "Safety|Carbon ...
# 28668  ["Essentials|Wireless internet", "Essentials|F...
# 28669  ["Essentials|Internet", "Essentials|Towels pro...
# 28670  ["Entertainment|Television", "Entertainment|Sa...
# 28671  ["Essentials|Wireless internet", "Essentials|F...
#
#                        HomeAway Location Type  Airbnb Property Plus  \
# 0                                         NaN                 False
# 1                                         NaN                 False
# 2                                         NaN                 False
# 3                                         NaN                 False
# 4                                         NaN                 False
# ...                                       ...                   ...
# 28667                                      {}                   NaN
# 28668                                      {}                   NaN
# 28669                                      {}                   NaN
# 28670                     {Downtown,Mountain}                   NaN
# 28671  {Beach,Downtown,"Near The Ocean",Town}                   NaN
#
#        Airbnb Home Collection  License  Airbnb Property ID  Airbnb Host ID  \
# 0                         NaN      NaN          13966456.0       4093742.0
# 1                         NaN      NaN          13966494.0      25531488.0
# 2                         NaN      NaN          13967114.0       5220741.0
# 3                         NaN      NaN          13969432.0      83279536.0
# 4                         NaN      NaN          13972983.0      32335069.0
# ...                       ...      ...                 ...             ...
# 28667                     NaN      NaN                 NaN             NaN
# 28668                     NaN      NaN                 NaN             NaN
# 28669                     NaN      NaN                 NaN             NaN
# 28670                     NaN      NaN                 NaN             NaN
# 28671                     NaN      NaN                 NaN             NaN
#
#        HomeAway Property ID  HomeAway Property Manager ID
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
# ...                     ...                           ...
# 28667             6715955ha                           NaN
# 28668             6724259ha                           NaN
# 28669             6726949ha                           NaN
# 28670             6776396ha                           NaN
# 28671             6785460ha  EnjoyBCN-Apartments-1004775u
#
# [28672 rows x 70 columns]

# %%
# Create new columns for amenities
annual_df['Has Pool'] = annual_df['Amenities'].apply(lambda x: 'pool' in x)
annual_df['Is Pet Friendly'] = annual_df['Amenities'].apply(lambda x: any(keyword in x for keyword in ['pets', 'pets allowed', 'pet friendly']))
annual_df['Has Air Conditioning'] = annual_df['Amenities'].apply(lambda x: any(keyword in x for keyword in ['air', 'conditioning']))

# Convert boolean values to True/False
annual_df['Has Pool'] = annual_df['Has Pool'].astype(bool)
annual_df['Is Pet Friendly'] = annual_df['Is Pet Friendly'].astype(bool)
annual_df['Has Air Conditioning'] = annual_df['Has Air Conditioning'].astype(bool)

annual_df
# Out:
#         Property ID                                      Listing Title  \
# 0       ab-13966456                              Double room in Gracia
# 1       ab-13966494             Room and bright and cosy flat in RAVAL
# 2       ab-13967114                     Habitación compartida en Sants
# 3       ab-13969432          Acogedor apartamento. Luminoso y soleado.
# 4       ab-13972983                                        Double room
# ...             ...                                                ...
# 28667  ha-6715955ha  Tapioles - 2 bed apartment with big balcony in...
# 28668  ha-6724259ha               110m2 apartment to rent in Barcelona
# 28669  ha-6726949ha                     Cozy Gaudí Apartment in Gracia
# 28670  ha-6776396ha  APTO. LOFT 2 - Apartment for 4 people in Barce...
# 28671  ha-6785460ha  Next to the Sagrada Família with terrace and s...
#
#       Property Type     Listing Type Created Date Last Scraped Date Country  \
# 0              Home      Shared room   2016-07-11        2024-04-21   Spain
# 1       Rental unit     Private room   2016-07-11        2024-04-18   Spain
# 2       Rental unit     Private room   2023-05-14        2024-01-22   Spain
# 3       Rental unit  Entire home/apt   2019-07-22        2024-04-29   Spain
# 4       Rental unit     Private room   2016-07-12        2024-04-17   Spain
# ...             ...              ...          ...               ...     ...
# 28667     Apartment  Entire home/apt          NaN        2024-04-30   Spain
# 28668     Apartment  Entire home/apt          NaN        2024-04-29   Spain
# 28669     Apartment  Entire home/apt          NaN        2024-05-01   Spain
# 28670     Apartment  Entire home/apt          NaN        2024-03-20   Spain
# 28671     Apartment  Entire home/apt          NaN        2024-04-30   Spain
#
#            State       City  Zipcode  ... Airbnb Property Plus  \
# 0      Barcelona  Barcelona      NaN  ...                False
# 1      Barcelona  Barcelona      NaN  ...                False
# 2      Barcelona  Barcelona      NaN  ...                False
# 3      Barcelona  Barcelona      NaN  ...                False
# 4      Barcelona  Barcelona      NaN  ...                False
# ...          ...        ...      ...  ...                  ...
# 28667  Barcelona  Barcelona      NaN  ...                  NaN
# 28668  Barcelona  Barcelona      NaN  ...                  NaN
# 28669  Barcelona  Barcelona      NaN  ...                  NaN
# 28670  Barcelona  Barcelona      NaN  ...                  NaN
# 28671  Barcelona  Barcelona      NaN  ...                  NaN
#
#        Airbnb Home Collection License  Airbnb Property ID  Airbnb Host ID  \
# 0                         NaN     NaN          13966456.0       4093742.0
# 1                         NaN     NaN          13966494.0      25531488.0
# 2                         NaN     NaN          13967114.0       5220741.0
# 3                         NaN     NaN          13969432.0      83279536.0
# 4                         NaN     NaN          13972983.0      32335069.0
# ...                       ...     ...                 ...             ...
# 28667                     NaN     NaN                 NaN             NaN
# 28668                     NaN     NaN                 NaN             NaN
# 28669                     NaN     NaN                 NaN             NaN
# 28670                     NaN     NaN                 NaN             NaN
# 28671                     NaN     NaN                 NaN             NaN
#
#        HomeAway Property ID  HomeAway Property Manager ID  Has Pool  \
# 0                       NaN                           NaN     False
# 1                       NaN                           NaN     False
# 2                       NaN                           NaN     False
# 3                       NaN                           NaN     False
# 4                       NaN                           NaN     False
# ...                     ...                           ...       ...
# 28667             6715955ha                           NaN     False
# 28668             6724259ha                           NaN     False
# 28669             6726949ha                           NaN     False
# 28670             6776396ha                           NaN     False
# 28671             6785460ha  EnjoyBCN-Apartments-1004775u      True
#
#        Is Pet Friendly  Has Air Conditioning
# 0                False                 False
# 1                False                  True
# 2                False                  True
# 3                False                  True
# 4                False                 False
# ...                ...                   ...
# 28667            False                  True
# 28668            False                  True
# 28669            False                  True
# 28670            False                  True
# 28671            False                  True
#
# [28672 rows x 73 columns]

# %% [markdown]
# ## Data cleaning

# %%
# Create a copy

annual_df1 = annual_df.copy()

# %%
# The Listing Type contains the type of property, we only want to keep the "EntireHome/apt"

annual_df1["Listing Type"].value_counts()
# Out:
# Listing Type
# Entire home/apt    15835
# Private room       12491
# Shared room          206
# Hotel room           140
# Name: count, dtype: int64

# %%
# Remove Private room, share room or hotel room

annual_df1 = annual_df1[annual_df1['Listing Type'] == 'Entire home/apt']
annual_df1
# Out:
#         Property ID                                      Listing Title  \
# 3       ab-13969432          Acogedor apartamento. Luminoso y soleado.
# 6       ab-13979120                         Barceloneta cozy apartment
# 10      ab-13986464                   Diputación Central Eixample Left
# 13      ab-13992866                              Sant Antoni apartment
# 16      ab-14004632         Stylish, centrally located, shared terrace
# ...             ...                                                ...
# 28667  ha-6715955ha  Tapioles - 2 bed apartment with big balcony in...
# 28668  ha-6724259ha               110m2 apartment to rent in Barcelona
# 28669  ha-6726949ha                     Cozy Gaudí Apartment in Gracia
# 28670  ha-6776396ha  APTO. LOFT 2 - Apartment for 4 people in Barce...
# 28671  ha-6785460ha  Next to the Sagrada Família with terrace and s...
#
#             Property Type     Listing Type Created Date Last Scraped Date  \
# 3             Rental unit  Entire home/apt   2019-07-22        2024-04-29
# 6                   Condo  Entire home/apt   2017-05-24        2024-04-29
# 10            Rental unit  Entire home/apt   2016-07-12        2023-06-07
# 13            Rental unit  Entire home/apt   2017-05-24        2024-04-27
# 16     Serviced apartment  Entire home/apt   2016-07-13        2024-05-03
# ...                   ...              ...          ...               ...
# 28667           Apartment  Entire home/apt          NaN        2024-04-30
# 28668           Apartment  Entire home/apt          NaN        2024-04-29
# 28669           Apartment  Entire home/apt          NaN        2024-05-01
# 28670           Apartment  Entire home/apt          NaN        2024-03-20
# 28671           Apartment  Entire home/apt          NaN        2024-04-30
#
#       Country      State       City  Zipcode  ... Airbnb Property Plus  \
# 3       Spain  Barcelona  Barcelona      NaN  ...                False
# 6       Spain  Barcelona  Barcelona      NaN  ...                False
# 10      Spain  Barcelona  Barcelona      NaN  ...                False
# 13      Spain  Barcelona  Barcelona      NaN  ...                False
# 16      Spain  Barcelona  Barcelona      NaN  ...                False
# ...       ...        ...        ...      ...  ...                  ...
# 28667   Spain  Barcelona  Barcelona      NaN  ...                  NaN
# 28668   Spain  Barcelona  Barcelona      NaN  ...                  NaN
# 28669   Spain  Barcelona  Barcelona      NaN  ...                  NaN
# 28670   Spain  Barcelona  Barcelona      NaN  ...                  NaN
# 28671   Spain  Barcelona  Barcelona      NaN  ...                  NaN
#
#        Airbnb Home Collection      License  Airbnb Property ID  \
# 3                         NaN          NaN          13969432.0
# 6                         NaN          NaN          13979120.0
# 10                        NaN  HUTB-008013          13986464.0
# 13                        NaN          NaN          13992866.0
# 16                        NaN  HUTB-004930          14004632.0
# ...                       ...          ...                 ...
# 28667                     NaN          NaN                 NaN
# 28668                     NaN          NaN                 NaN
# 28669                     NaN          NaN                 NaN
# 28670                     NaN          NaN                 NaN
# 28671                     NaN          NaN                 NaN
#
#        Airbnb Host ID  HomeAway Property ID  HomeAway Property Manager ID  \
# 3          83279536.0                   NaN                           NaN
# 6          71922291.0               2998148                           NaN
# 10          1391607.0                   NaN                           NaN
# 13         83548422.0                   NaN                           NaN
# 16          5878688.0                   NaN                           NaN
# ...               ...                   ...                           ...
# 28667             NaN             6715955ha                           NaN
# 28668             NaN             6724259ha                           NaN
# 28669             NaN             6726949ha                           NaN
# 28670             NaN             6776396ha                           NaN
# 28671             NaN             6785460ha  EnjoyBCN-Apartments-1004775u
#
#        Has Pool  Is Pet Friendly  Has Air Conditioning
# 3         False            False                  True
# 6         False            False                  True
# 10        False            False                  True
# 13        False            False                  True
# 16        False            False                  True
# ...         ...              ...                   ...
# 28667     False            False                  True
# 28668     False            False                  True
# 28669     False            False                  True
# 28670     False            False                  True
# 28671      True            False                  True
#
# [15835 rows x 73 columns]

# %%
# The Property ID is ab-number or ha-number, we only want to keep the number as the ID and change the dtype from object to integer

annual_df1['Property ID'] = annual_df1['Property ID'].str.extract(r'(\d+)')
annual_df1['Property ID'] = annual_df1['Property ID'].astype(int)

# %%
# Create a copy

annual_df2 = annual_df1.copy()

# %%
annual_df2.columns
# Out:
# Index(['Property ID', 'Listing Title', 'Property Type', 'Listing Type',
#        'Created Date', 'Last Scraped Date', 'Country', 'State', 'City',
#        'Zipcode', 'Neighborhood', 'Metropolitan Statistical Area',
#        'Currency Native', 'Average Daily Rate (USD)',
#        'Average Daily Rate (Native)', 'Annual Revenue LTM (USD)',
#        'Annual Revenue LTM (Native)', 'Occupancy Rate LTM',
#        'Number of Bookings LTM', 'Number of Reviews', 'Bedrooms', 'Bathrooms',
#        'Max Guests', 'Calendar Last Updated', 'Response Rate',
#        'Airbnb Response Time (Text)', 'Airbnb Superhost',
#        'HomeAway Premier Partner', 'Cancellation Policy',
#        'Security Deposit (USD)', 'Security Deposit (Native)',
#        'Cleaning Fee (USD)', 'Cleaning Fee (Native)', 'Extra People Fee (USD)',
#        'Extra People Fee (Native)', 'Published Nightly Rate (USD)',
#        'Published Monthly Rate (USD)', 'Published Weekly Rate (USD)',
#        'Check-in Time', 'Checkout Time', 'Minimum Stay',
#        'Count Reservation Days LTM', 'Count Available Days LTM',
#        'Count Blocked Days LTM', 'Number of Photos', 'Instantbook Enabled',
#        'Listing URL', 'Listing Main Image URL', 'Listing Images', 'Latitude',
#        'Longitude', 'Exact Location', 'Overall Rating',
#        'Airbnb Communication Rating', 'Airbnb Accuracy Rating',
#        'Airbnb Cleanliness Rating', 'Airbnb Checkin Rating',
#        'Airbnb Location Rating', 'Airbnb Value Rating', 'Pets Allowed',
#        'Integrated Property Manager', 'Amenities', 'HomeAway Location Type',
#        'Airbnb Property Plus', 'Airbnb Home Collection', 'License',
#        'Airbnb Property ID', 'Airbnb Host ID', 'HomeAway Property ID',
#        'HomeAway Property Manager ID', 'Has Pool', 'Is Pet Friendly',
#        'Has Air Conditioning'],
#       dtype='object')

# %%
# We are going to drop columns that we don't need in our dataset

annual_df2.drop(columns=['Listing Title', 'Property Type', 'Listing Type', 'Created Date', 'Last Scraped Date', 'Country', 'State', 'City', 'Zipcode', 'Metropolitan Statistical Area', 'Currency Native', 'Average Daily Rate (USD)', 'Annual Revenue LTM (USD)', 'Number of Bookings LTM', 'Number of Reviews', 'Max Guests', 'Calendar Last Updated', 'Response Rate', 'Airbnb Response Time (Text)', 'Airbnb Superhost', 'HomeAway Premier Partner', 'Cancellation Policy', 'Security Deposit (USD)', 'Security Deposit (Native)', 'Cleaning Fee (USD)', 'Cleaning Fee (Native)', 'Extra People Fee (USD)', 'Extra People Fee (Native)', 'Published Nightly Rate (USD)', 'Published Monthly Rate (USD)', 'Published Weekly Rate (USD)', 'Check-in Time', 'Checkout Time', 'Minimum Stay', 'Count Reservation Days LTM', 'Count Available Days LTM', 'Count Blocked Days LTM', 'Number of Photos', 'Instantbook Enabled', 'Listing URL', 'Listing Main Image URL', 'Listing Images', 'Exact Location', 'Overall Rating', 'Airbnb Communication Rating', 'Airbnb Accuracy Rating', 'Airbnb Cleanliness Rating', 'Airbnb Checkin Rating', 'Airbnb Location Rating', 'Airbnb Value Rating', 'Pets Allowed', 'Integrated Property Manager', 'Amenities', 'HomeAway Location Type', 'Airbnb Property Plus', 'Airbnb Home Collection', 'License', 'Airbnb Property ID', 'Airbnb Host ID', 'HomeAway Property ID', 'HomeAway Property Manager ID'], inplace=True)

# %%
# We are going to change the name of some of the columns

annual_df2.rename(columns={'Average Daily Rate (Native)': 'Average Daily Rate', 'Annual Revenue LTM (Native)': 'Annual Revenue', 'Occupancy Rate LTM': 'Occupancy Rate'}, inplace=True)

# %%
# Create a copy

annual_df3 = annual_df2.copy()

# %%
# We are going to focus on cleaning the data from the annual_df dataset

annual_df3
# Out:
#        Property ID                           Neighborhood  Average Daily Rate  \
# 3         13969432  Sant Pere, Santa Caterina i la Ribera              109.19
# 6         13979120                         la Barceloneta               96.00
# 10        13986464         la Nova Esquerra de l'Eixample              184.95
# 13        13992866                            Sant Antoni               84.05
# 16        14004632                 la Dreta de l'Eixample              320.97
# ...            ...                                    ...                 ...
# 28667      6715955                           el Poble Sec                 NaN
# 28668      6724259                     la Sagrada Família                 NaN
# 28669      6726949                      la Vila de Gràcia                 NaN
# 28670      6776396                 Sant Gervasi - Galvany                 NaN
# 28671      6785460                     la Sagrada Família                 NaN
#
#        Annual Revenue  Occupancy Rate  Bedrooms  Bathrooms   Latitude  \
# 3               437.0           1.000         1        1.0  41.382480
# 6                96.0           1.000         1        1.0  41.378850
# 10            19605.0           0.791         3        1.0  41.382530
# 13              420.0           1.000         3        1.0  41.378020
# 16           109450.0           0.942         2        2.0  41.392620
# ...               ...             ...       ...        ...        ...
# 28667             NaN           0.481         2        1.0  41.373940
# 28668             NaN           0.769         3        2.0  41.404500
# 28669             NaN           0.775         2        1.0  41.408594
# 28670             NaN             NaN         2        3.0  41.398920
# 28671             NaN           0.452         2        1.0  41.405434
#
#        Longitude  Has Pool  Is Pet Friendly  Has Air Conditioning
# 3       2.182920     False            False                  True
# 6       2.190840     False            False                  True
# 10      2.157520     False            False                  True
# 13      2.160660     False            False                  True
# 16      2.174230     False            False                  True
# ...          ...       ...              ...                   ...
# 28667   2.164641     False            False                  True
# 28668   2.172212     False            False                  True
# 28669   2.159238     False            False                  True
# 28670   2.146227     False            False                  True
# 28671   2.174583      True            False                  True
#
# [15835 rows x 12 columns]

# %%
annual_df3.to_csv('annual_df3.csv', index=False)

# %%
# Check Nans

annual_df3.isnull().sum()
# Out:
# Property ID                0
# Neighborhood               6
# Average Daily Rate      4631
# Annual Revenue          1242
# Occupancy Rate          3786
# Bedrooms                   0
# Bathrooms                  0
# Latitude                   0
# Longitude                  0
# Has Pool                   0
# Is Pet Friendly            0
# Has Air Conditioning       0
# dtype: int64

# %%
# We are going to change the Average Daily Rate NaN rows 0

annual_df3['Average Daily Rate'].fillna(0, inplace=True)

# %%
# We are going to change the Annual Revenue NaN rows 0

annual_df3['Annual Revenue'].fillna(0, inplace=True)

# %%
# We are going to change the Occupancy NaN rows 0

annual_df3['Occupancy Rate'].fillna(0, inplace=True)

# %%
# We are going to change the Neighborhood NaN rows the majority

annual_df3['Neighborhood'].value_counts()
# Out:
# Neighborhood
# la Dreta de l'Eixample                   1962
# Sant Pere, Santa Caterina i la Ribera    1210
# el Raval                                 1079
# la Sagrada Família                       1054
# el Barri Gòtic                            981
#                                          ...
# la Guineueta                                4
# el Bon Pastor                               4
# Canyelles                                   3
# la Clota                                    3
# Torre Baró                                  3
# Name: count, Length: 68, dtype: int64

# %%
annual_df3['Neighborhood'].fillna("la Dreta de l'Eixample", inplace=True)

# %%
annual_df3.dtypes
# Out:
# Property ID               int64
# Neighborhood             object
# Average Daily Rate      float64
# Annual Revenue          float64
# Occupancy Rate          float64
# Bedrooms                  int64
# Bathrooms               float64
# Latitude                float64
# Longitude               float64
# Has Pool                   bool
# Is Pet Friendly            bool
# Has Air Conditioning       bool
# dtype: object

# %%
neighborhood = pd.read_excel("/Users/clark/Desktop/ironhack/final-project/files/neighborhoods.xlsx")
neighborhood
# Out:
#                                     Neighborhood  Seasonality
# 0                                       Can Baró         0.53
# 1                                      Canyelles         0.12
# 2   Diagonal Mar i el Front Marítim del Poblenou         0.46
# 3                               el Baix Guinardó         0.31
# 4                                 el Barri Gòtic         0.72
# ..                                           ...          ...
# 63                                    Torre Baró         0.06
# 64                     Vallcarca i els Penitents         0.18
# 65         Vallvidrera, el Tibidabo i les Planes         0.21
# 66                                        Verdun         0.06
# 67                 Vilapicina i la Torre Llobeta         0.37
#
# [68 rows x 2 columns]

# %%
annual_df3 = pd.merge(annual_df3, neighborhood, on='Neighborhood', how='left')

# %% [markdown]
# ## EDA

# %%
# Import necessary libraries

import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings('ignore')

# %%
# Create a copy

annual_df4 = annual_df3.copy()

# %%
annual_df4.shape
# Out:
# (15835, 13)

# %%
annual_df4.describe()
# Out:
#         Property ID  Average Daily Rate  Annual Revenue  Occupancy Rate  \
# count  1.583500e+04        15835.000000    15835.000000    15835.000000
# mean   3.841641e+17          178.739751    26384.043701        0.557942
# std    4.446817e+17          286.608442    38554.492280        0.381720
# min    1.747500e+04            0.000000        0.000000        0.000000
# 25%    1.977931e+07            0.000000        0.000000        0.069000
# 50%    4.981867e+07          146.180000     5534.000000        0.691000
# 75%    8.563613e+17          243.840000    45344.000000        0.895000
# max    1.146133e+18        10878.860000   602386.000000        1.000000
#
#            Bedrooms     Bathrooms      Latitude     Longitude   Seasonality
# count  15835.000000  15835.000000  15835.000000  15835.000000  15835.000000
# mean       2.082223      1.416198     41.391657      2.167584      0.635387
# std        1.236853      0.806664      0.013090      0.017683      0.163900
# min        0.000000      0.000000     41.349834      2.077490      0.030000
# 25%        1.000000      1.000000     41.381247      2.157200      0.530000
# 50%        2.000000      1.000000     41.389770      2.168371      0.690000
# 75%        3.000000      2.000000     41.400999      2.178283      0.740000
# max       50.000000     50.000000     41.458057      2.227710      0.840000

# %%
# Separate the numerical from the categorical columns

numerical_columns = annual_df4.select_dtypes("number")
categorical_columns = annual_df4.select_dtypes("object")

# %%
# Probability distributions

for col in numerical_columns.columns:
  sns.distplot(numerical_columns[col])
  plt.show()

# %%
# Calculate the exact outliers range

IQR = abs(np.quantile(annual_df4["Annual Revenue"], .25) - np.quantile(annual_df4["Annual Revenue"], .75)) * 1.5
lower_boundary = np.quantile(annual_df4["Annual Revenue"], .25) - IQR
upper_boundary = np.quantile(annual_df4["Annual Revenue"], .75) + IQR

# Outliers for this column are values smaller than lower_boundary or bigger than upper_boundary

lower_boundary, upper_boundary
# Out:
# (-68016.0, 113360.0)

# %%
# Correlation between the features and the target

correlations_matrix = numerical_columns.corr()

correlations_matrix["Annual Revenue"].sort_values(ascending=False)
# Out:
# Annual Revenue        1.000000
# Occupancy Rate        0.482713
# Average Daily Rate    0.374894
# Bedrooms              0.246512
# Bathrooms             0.212899
# Seasonality           0.072683
# Latitude              0.017140
# Longitude            -0.008796
# Property ID          -0.241266
# Name: Annual Revenue, dtype: float64

# %%
# Bedrooms has the highest correlation

plt.scatter(annual_df3["Annual Revenue"], annual_df3["Occupancy Rate"])

# %%
# For now, when analysing categorical we can use barplots

sns.barplot(x=annual_df3["Neighborhood"], y=annual_df3["Annual Revenue"])
# Out:
# <Axes: xlabel='Neighborhood', ylabel='Annual Revenue'>

# %%
# Let's check the correlation amongst features - multicolinearity

mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
# Create a copy

annual_final = annual_df4.copy()
annual_final
# Out:
#        Property ID                           Neighborhood  Average Daily Rate  \
# 0         13969432  Sant Pere, Santa Caterina i la Ribera              109.19
# 1         13979120                         la Barceloneta               96.00
# 2         13986464         la Nova Esquerra de l'Eixample              184.95
# 3         13992866                            Sant Antoni               84.05
# 4         14004632                 la Dreta de l'Eixample              320.97
# ...            ...                                    ...                 ...
# 15830      6715955                           el Poble Sec                0.00
# 15831      6724259                     la Sagrada Família                0.00
# 15832      6726949                      la Vila de Gràcia                0.00
# 15833      6776396                 Sant Gervasi - Galvany                0.00
# 15834      6785460                     la Sagrada Família                0.00
#
#        Annual Revenue  Occupancy Rate  Bedrooms  Bathrooms   Latitude  \
# 0               437.0           1.000         1        1.0  41.382480
# 1                96.0           1.000         1        1.0  41.378850
# 2             19605.0           0.791         3        1.0  41.382530
# 3               420.0           1.000         3        1.0  41.378020
# 4            109450.0           0.942         2        2.0  41.392620
# ...               ...             ...       ...        ...        ...
# 15830             0.0           0.481         2        1.0  41.373940
# 15831             0.0           0.769         3        2.0  41.404500
# 15832             0.0           0.775         2        1.0  41.408594
# 15833             0.0           0.000         2        3.0  41.398920
# 15834             0.0           0.452         2        1.0  41.405434
#
#        Longitude  Has Pool  Is Pet Friendly  Has Air Conditioning  Seasonality
# 0       2.182920     False            False                  True         0.76
# 1       2.190840     False            False                  True         0.60
# 2       2.157520     False            False                  True         0.73
# 3       2.160660     False            False                  True         0.67
# 4       2.174230     False            False                  True         0.74
# ...          ...       ...              ...                   ...          ...
# 15830   2.164641     False            False                  True         0.49
# 15831   2.172212     False            False                  True         0.72
# 15832   2.159238     False            False                  True         0.64
# 15833   2.146227     False            False                  True         0.51
# 15834   2.174583      True            False                  True         0.72
#
# [15835 rows x 13 columns]

# %%
# Encoding Categorical Variables

annual_final = pd.get_dummies(annual_final, drop_first=True)
annual_final
# Out:
#        Property ID  Average Daily Rate  Annual Revenue  Occupancy Rate  \
# 0         13969432              109.19           437.0           1.000
# 1         13979120               96.00            96.0           1.000
# 2         13986464              184.95         19605.0           0.791
# 3         13992866               84.05           420.0           1.000
# 4         14004632              320.97        109450.0           0.942
# ...            ...                 ...             ...             ...
# 15830      6715955                0.00             0.0           0.481
# 15831      6724259                0.00             0.0           0.769
# 15832      6726949                0.00             0.0           0.775
# 15833      6776396                0.00             0.0           0.000
# 15834      6785460                0.00             0.0           0.452
#
#        Bedrooms  Bathrooms   Latitude  Longitude  Has Pool  Is Pet Friendly  \
# 0             1        1.0  41.382480   2.182920     False            False
# 1             1        1.0  41.378850   2.190840     False            False
# 2             3        1.0  41.382530   2.157520     False            False
# 3             3        1.0  41.378020   2.160660     False            False
# 4             2        2.0  41.392620   2.174230     False            False
# ...         ...        ...        ...        ...       ...              ...
# 15830         2        1.0  41.373940   2.164641     False            False
# 15831         3        2.0  41.404500   2.172212     False            False
# 15832         2        1.0  41.408594   2.159238     False            False
# 15833         2        3.0  41.398920   2.146227     False            False
# 15834         2        1.0  41.405434   2.174583      True            False
#
#        ...  Neighborhood_la Salut  Neighborhood_la Teixonera  \
# 0      ...                  False                      False
# 1      ...                  False                      False
# 2      ...                  False                      False
# 3      ...                  False                      False
# 4      ...                  False                      False
# ...    ...                    ...                        ...
# 15830  ...                  False                      False
# 15831  ...                  False                      False
# 15832  ...                  False                      False
# 15833  ...                  False                      False
# 15834  ...                  False                      False
#
#        Neighborhood_la Trinitat Vella  Neighborhood_la Vall d'Hebron  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
# ...                               ...                            ...
# 15830                           False                          False
# 15831                           False                          False
# 15832                           False                          False
# 15833                           False                          False
# 15834                           False                          False
#
#        Neighborhood_la Verneda i la Pau  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 15830                             False
# 15831                             False
# 15832                             False
# 15833                             False
# 15834                             False
#
#        Neighborhood_la Vila Olímpica del Poblenou  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 15830                                       False
# 15831                                       False
# 15832                                       False
# 15833                                       False
# 15834                                       False
#
#        Neighborhood_la Vila de Gràcia  Neighborhood_les Corts  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
# ...                               ...                     ...
# 15830                           False                   False
# 15831                           False                   False
# 15832                            True                   False
# 15833                           False                   False
# 15834                           False                   False
#
#        Neighborhood_les Roquetes  Neighborhood_les Tres Torres
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 15830                      False                         False
# 15831                      False                         False
# 15832                      False                         False
# 15833                      False                         False
# 15834                      False                         False
#
# [15835 rows x 79 columns]

# %%
# X-y split

X = annual_final.drop(["Annual Revenue", "Property ID"], axis=1)
y = annual_final["Annual Revenue"]

# Train-test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train
# Out:
#        Average Daily Rate  Occupancy Rate  Bedrooms  Bathrooms   Latitude  \
# 14302              178.28           0.560         2        1.0  41.379080
# 3130               202.41           0.953         2        1.0  41.408720
# 2474               211.39           0.986         0        1.0  41.384800
# 3931               180.07           0.564         1        1.0  41.377340
# 2627               186.92           0.962         2        1.0  41.374330
# ...                   ...             ...       ...        ...        ...
# 13418              303.98           0.498         3        1.5  41.377411
# 5390               345.35           0.111         3        2.5  41.384310
# 860                190.28           1.000         1        1.0  41.405070
# 15795                0.00           0.846         3        1.0  41.375980
# 7270                 0.00           0.000         2        1.0  41.371200
#
#        Longitude  Has Pool  Is Pet Friendly  Has Air Conditioning  \
# 14302    2.16613     False            False                  True
# 3130     2.17510     False            False                  True
# 2474     2.17100     False            False                  True
# 3931     2.16273     False            False                  True
# 2627     2.14045     False            False                  True
# ...          ...       ...              ...                   ...
# 13418    2.14521     False            False                  True
# 5390     2.14527     False            False                  True
# 860      2.17387     False            False                  True
# 15795    2.15724     False            False                 False
# 7270     2.16844     False            False                  True
#
#        Seasonality  ...  Neighborhood_la Salut  Neighborhood_la Teixonera  \
# 14302         0.84  ...                  False                      False
# 3130          0.72  ...                  False                      False
# 2474          0.72  ...                  False                      False
# 3931          0.67  ...                  False                      False
# 2627          0.61  ...                  False                      False
# ...            ...  ...                    ...                        ...
# 13418         0.81  ...                  False                      False
# 5390          0.73  ...                  False                      False
# 860           0.72  ...                  False                      False
# 15795         0.67  ...                  False                      False
# 7270          0.49  ...                  False                      False
#
#        Neighborhood_la Trinitat Vella  Neighborhood_la Vall d'Hebron  \
# 14302                           False                          False
# 3130                            False                          False
# 2474                            False                          False
# 3931                            False                          False
# 2627                            False                          False
# ...                               ...                            ...
# 13418                           False                          False
# 5390                            False                          False
# 860                             False                          False
# 15795                           False                          False
# 7270                            False                          False
#
#        Neighborhood_la Verneda i la Pau  \
# 14302                             False
# 3130                              False
# 2474                              False
# 3931                              False
# 2627                              False
# ...                                 ...
# 13418                             False
# 5390                              False
# 860                               False
# 15795                             False
# 7270                              False
#
#        Neighborhood_la Vila Olímpica del Poblenou  \
# 14302                                       False
# 3130                                        False
# 2474                                        False
# 3931                                        False
# 2627                                        False
# ...                                           ...
# 13418                                       False
# 5390                                        False
# 860                                         False
# 15795                                       False
# 7270                                        False
#
#        Neighborhood_la Vila de Gràcia  Neighborhood_les Corts  \
# 14302                           False                   False
# 3130                            False                   False
# 2474                            False                   False
# 3931                            False                   False
# 2627                            False                   False
# ...                               ...                     ...
# 13418                           False                   False
# 5390                            False                   False
# 860                             False                   False
# 15795                           False                   False
# 7270                            False                   False
#
#        Neighborhood_les Roquetes  Neighborhood_les Tres Torres
# 14302                      False                         False
# 3130                       False                         False
# 2474                       False                         False
# 3931                       False                         False
# 2627                       False                         False
# ...                          ...                           ...
# 13418                      False                         False
# 5390                       False                         False
# 860                        False                         False
# 15795                      False                         False
# 7270                       False                         False
#
# [11084 rows x 77 columns]

# %%
# Start the scaler object

scaler = StandardScaler()

# Fit the scaler object only on the training data to avoid data leakage

scaler.fit(X_train)

# Transform training and the testing data

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Start the model object

lm = LinearRegression()

# Fit the model object on the training set

lm.fit(X_train_scaled, y_train)

# Get predictions for the test set

predictions = lm.predict(X_test_scaled)

# %%
# Calculate your metrics

rmse = mean_squared_error(y_test, predictions, squared=False)
mae = mean_absolute_error(y_test, predictions)
print("R2_score:", round(r2_score(y_test, predictions), 2))
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# R2_score: 0.37
# RMSE: 30347.38871977413
# MAE: 20725.580815321984

# %% [markdown]
# **Let's try and improve the model**

# %%
# A good place to start is by getting the regression prot from the predictions vs the true values

sns.regplot(x=y_test, y=predictions, line_kws={"color": "black"}, scatter_kws={"color": "grey"})
# Out:
# <Axes: xlabel='Annual Revenue'>

# %%
# Log scaling

y_train_scaled = y_train.apply(lambda x: np.log(x) if x > 0 else 0)
y_test_scaled = y_test.apply(lambda x: np.log(x) if x > 0 else 0)

y_train_scaled
# Out:
# 14302     9.033484
# 3130     10.893791
# 2474     11.242599
# 3931     10.280930
# 2627     10.412471
#            ...
# 13418    10.361355
# 5390      5.843544
# 860       5.247024
# 15795     0.000000
# 7270      0.000000
# Name: Annual Revenue, Length: 11084, dtype: float64

# %%
# Look at how log scaling changed the distribution

sns.distplot(y_train_scaled, bins=10)
# Out:
# <Axes: xlabel='Annual Revenue', ylabel='Density'>

# %%
# Compared to what we had before scaling

sns.distplot(y_train, bins=10)
# Out:
# <Axes: xlabel='Annual Revenue', ylabel='Density'>

# %%
# Now let's check the model again

lm = LinearRegression()

lm.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
# Let's calculate R2 again

predictions = lm.predict(X_test_scaled)
print("R2_score:", round(r2_score(y_test_scaled, predictions), 2))
# Out:
# R2_score: 0.62

# %%
sns.color_palette("colorblind")
sns.regplot(x=y_test_scaled, y=predictions)
# Out:
# <Axes: xlabel='Annual Revenue'>

# %% [markdown]
# Model has improved considerably, let's check how the models improves if we remove the outliers

# %%
result_df = X_test
result_df["target"] = y_test
result_df["scaled_target"] = y_test_scaled
result_df["error"] = y_test_scaled - predictions
result_df.sort_values("error", ascending=False)
# Out:
#        Average Daily Rate  Occupancy Rate  Bedrooms  Bathrooms   Latitude  \
# 10399                0.00           0.000         4        3.0  41.402883
# 8749                 0.00           0.000         2        1.0  41.389950
# 9954                 0.00           0.000         2        2.0  41.383040
# 10398                0.00           0.000         1        1.0  41.390696
# 14253                0.00           0.000         1        1.0  41.383770
# ...                   ...             ...       ...        ...        ...
# 10356             3116.13           1.000         3        2.0  41.390220
# 9534              4829.05           0.036         6        4.0  41.380232
# 4303              5598.50           0.083         4        4.5  41.378060
# 10216             4067.28           1.000         2        1.0  41.406517
# 10400             3706.85           1.000         3        2.0  41.403940
#
#        Longitude  Has Pool  Is Pet Friendly  Has Air Conditioning  \
# 10399   2.142472     False            False                  True
# 8749    2.178930     False            False                  True
# 9954    2.161760     False            False                 False
# 10398   2.169890      True            False                  True
# 14253   2.177614     False            False                 False
# ...          ...       ...              ...                   ...
# 10356   2.168600      True            False                  True
# 9534    2.146778     False            False                  True
# 4303    2.183490     False            False                  True
# 10216   2.179246     False            False                  True
# 10400   2.144820     False            False                  True
#
#        Seasonality  ...  Neighborhood_la Vall d'Hebron  \
# 10399         0.51  ...                          False
# 8749          0.76  ...                          False
# 9954          0.67  ...                          False
# 10398         0.74  ...                          False
# 14253         0.72  ...                          False
# ...            ...  ...                            ...
# 10356         0.74  ...                          False
# 9534          0.73  ...                          False
# 4303          0.72  ...                          False
# 10216         0.72  ...                          False
# 10400         0.22  ...                          False
#
#        Neighborhood_la Verneda i la Pau  \
# 10399                             False
# 8749                              False
# 9954                              False
# 10398                             False
# 14253                             False
# ...                                 ...
# 10356                             False
# 9534                              False
# 4303                              False
# 10216                             False
# 10400                             False
#
#        Neighborhood_la Vila Olímpica del Poblenou  \
# 10399                                       False
# 8749                                        False
# 9954                                        False
# 10398                                       False
# 14253                                       False
# ...                                           ...
# 10356                                       False
# 9534                                        False
# 4303                                        False
# 10216                                       False
# 10400                                       False
#
#        Neighborhood_la Vila de Gràcia  Neighborhood_les Corts  \
# 10399                           False                   False
# 8749                            False                   False
# 9954                            False                   False
# 10398                           False                   False
# 14253                           False                   False
# ...                               ...                     ...
# 10356                           False                   False
# 9534                            False                   False
# 4303                            False                   False
# 10216                           False                   False
# 10400                           False                   False
#
#        Neighborhood_les Roquetes  Neighborhood_les Tres Torres   target  \
# 10399                      False                         False  10254.0
# 8749                       False                         False  16548.0
# 9954                       False                         False  10079.0
# 10398                      False                         False   5560.0
# 14253                      False                         False   7769.0
# ...                          ...                           ...      ...
# 10356                      False                         False   9348.0
# 9534                       False                         False   4829.0
# 4303                       False                         False  22394.0
# 10216                      False                         False  32538.0
# 10400                      False                         False   7414.0
#
#        scaled_target      error
# 10399       9.235423   7.929535
# 8749        9.714021   7.830252
# 9954        9.218209   7.549529
# 10398       8.623353   7.408530
# 14253       8.957897   7.383943
# ...              ...        ...
# 10356       9.142918 -11.984015
# 9534        8.482395 -12.855903
# 4303       10.016548 -14.351351
# 10216      10.390164 -15.307203
# 10400       8.911125 -15.551745
#
# [4751 rows x 80 columns]

# %%
df_no_outliers = annual_final[annual_final["Annual Revenue"] < 113360.0]
df_no_outliers
# Out:
#        Property ID  Average Daily Rate  Annual Revenue  Occupancy Rate  \
# 0         13969432              109.19           437.0           1.000
# 1         13979120               96.00            96.0           1.000
# 2         13986464              184.95         19605.0           0.791
# 3         13992866               84.05           420.0           1.000
# 4         14004632              320.97        109450.0           0.942
# ...            ...                 ...             ...             ...
# 15830      6715955                0.00             0.0           0.481
# 15831      6724259                0.00             0.0           0.769
# 15832      6726949                0.00             0.0           0.775
# 15833      6776396                0.00             0.0           0.000
# 15834      6785460                0.00             0.0           0.452
#
#        Bedrooms  Bathrooms   Latitude  Longitude  Has Pool  Is Pet Friendly  \
# 0             1        1.0  41.382480   2.182920     False            False
# 1             1        1.0  41.378850   2.190840     False            False
# 2             3        1.0  41.382530   2.157520     False            False
# 3             3        1.0  41.378020   2.160660     False            False
# 4             2        2.0  41.392620   2.174230     False            False
# ...         ...        ...        ...        ...       ...              ...
# 15830         2        1.0  41.373940   2.164641     False            False
# 15831         3        2.0  41.404500   2.172212     False            False
# 15832         2        1.0  41.408594   2.159238     False            False
# 15833         2        3.0  41.398920   2.146227     False            False
# 15834         2        1.0  41.405434   2.174583      True            False
#
#        ...  Neighborhood_la Salut  Neighborhood_la Teixonera  \
# 0      ...                  False                      False
# 1      ...                  False                      False
# 2      ...                  False                      False
# 3      ...                  False                      False
# 4      ...                  False                      False
# ...    ...                    ...                        ...
# 15830  ...                  False                      False
# 15831  ...                  False                      False
# 15832  ...                  False                      False
# 15833  ...                  False                      False
# 15834  ...                  False                      False
#
#        Neighborhood_la Trinitat Vella  Neighborhood_la Vall d'Hebron  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
# ...                               ...                            ...
# 15830                           False                          False
# 15831                           False                          False
# 15832                           False                          False
# 15833                           False                          False
# 15834                           False                          False
#
#        Neighborhood_la Verneda i la Pau  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 15830                             False
# 15831                             False
# 15832                             False
# 15833                             False
# 15834                             False
#
#        Neighborhood_la Vila Olímpica del Poblenou  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 15830                                       False
# 15831                                       False
# 15832                                       False
# 15833                                       False
# 15834                                       False
#
#        Neighborhood_la Vila de Gràcia  Neighborhood_les Corts  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
# ...                               ...                     ...
# 15830                           False                   False
# 15831                           False                   False
# 15832                            True                   False
# 15833                           False                   False
# 15834                           False                   False
#
#        Neighborhood_les Roquetes  Neighborhood_les Tres Torres
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 15830                      False                         False
# 15831                      False                         False
# 15832                      False                         False
# 15833                      False                         False
# 15834                      False                         False
#
# [15347 rows x 79 columns]

# %%
df_no_outliers[numerical_columns.columns] = df_no_outliers[numerical_columns.columns].applymap(lambda x: np.log(x) if x > 0 else 0) # this logic will work well as long as we don't have negative values
# .applymap() is similar to .apply() but it applies the function on the entire DataFrame

df_no_outliers
# Out:
#        Property ID  Average Daily Rate  Annual Revenue  Occupancy Rate  \
# 0        16.452382            4.693089        6.079933        0.000000
# 1        16.453075            4.564348        4.564348        0.000000
# 2        16.453601            5.220086        9.883540       -0.234457
# 3        16.454058            4.431412        6.040255        0.000000
# 4        16.454899            5.771348       11.603223       -0.059750
# ...            ...                 ...             ...             ...
# 15830    15.719997            0.000000        0.000000       -0.731888
# 15831    15.721232            0.000000        0.000000       -0.262664
# 15832    15.721632            0.000000        0.000000       -0.254892
# 15833    15.728956            0.000000        0.000000        0.000000
# 15834    15.730293            0.000000        0.000000       -0.794073
#
#        Bedrooms  Bathrooms  Latitude  Longitude  Has Pool  Is Pet Friendly  \
# 0      0.000000   0.000000  3.722858   0.780663     False            False
# 1      0.000000   0.000000  3.722770   0.784285     False            False
# 2      1.098612   0.000000  3.722859   0.768959     False            False
# 3      1.098612   0.000000  3.722750   0.770414     False            False
# 4      0.693147   0.693147  3.723103   0.776675     False            False
# ...         ...        ...       ...        ...       ...              ...
# 15830  0.693147   0.000000  3.722651   0.772255     False            False
# 15831  1.098612   0.693147  3.723390   0.775746     False            False
# 15832  0.693147   0.000000  3.723488   0.769755     False            False
# 15833  0.693147   1.098612  3.723255   0.763711     False            False
# 15834  0.693147   0.000000  3.723412   0.776837      True            False
#
#        ...  Neighborhood_la Salut  Neighborhood_la Teixonera  \
# 0      ...                  False                      False
# 1      ...                  False                      False
# 2      ...                  False                      False
# 3      ...                  False                      False
# 4      ...                  False                      False
# ...    ...                    ...                        ...
# 15830  ...                  False                      False
# 15831  ...                  False                      False
# 15832  ...                  False                      False
# 15833  ...                  False                      False
# 15834  ...                  False                      False
#
#        Neighborhood_la Trinitat Vella  Neighborhood_la Vall d'Hebron  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
# ...                               ...                            ...
# 15830                           False                          False
# 15831                           False                          False
# 15832                           False                          False
# 15833                           False                          False
# 15834                           False                          False
#
#        Neighborhood_la Verneda i la Pau  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 15830                             False
# 15831                             False
# 15832                             False
# 15833                             False
# 15834                             False
#
#        Neighborhood_la Vila Olímpica del Poblenou  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 15830                                       False
# 15831                                       False
# 15832                                       False
# 15833                                       False
# 15834                                       False
#
#        Neighborhood_la Vila de Gràcia  Neighborhood_les Corts  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
# ...                               ...                     ...
# 15830                           False                   False
# 15831                           False                   False
# 15832                            True                   False
# 15833                           False                   False
# 15834                           False                   False
#
#        Neighborhood_les Roquetes  Neighborhood_les Tres Torres
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 15830                      False                         False
# 15831                      False                         False
# 15832                      False                         False
# 15833                      False                         False
# 15834                      False                         False
#
# [15347 rows x 79 columns]

# %%
# X-y split: here we keep only the data we will use to train the model
X = df_no_outliers.drop(["Annual Revenue", "Property ID"], axis=1) # check results without the multicolinear columns: "ic1", "ic2", "ic3", "hvp1"
y = df_no_outliers["Annual Revenue"]

# %%
# Train-test split:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train the model

lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
numerical_columns = df_no_outliers.select_dtypes("number")
categorical_columns = df_no_outliers.select_dtypes("object")

# %%
correlations_matrix = numerical_columns.corr()

correlations_matrix["Annual Revenue"].sort_values(ascending=False)
# Out:
# Annual Revenue        1.000000
# Average Daily Rate    0.926438
# Seasonality           0.039068
# Bedrooms              0.035732
# Latitude              0.000665
# Bathrooms            -0.023033
# Longitude            -0.024681
# Property ID          -0.035799
# Occupancy Rate       -0.116389
# Name: Annual Revenue, dtype: float64

# %%
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
# Test the model

predictions = lm.predict(X_test)
print("R2_score:", round(r2_score(y_test, predictions), 2))
# Out:
# R2_score: 0.89
